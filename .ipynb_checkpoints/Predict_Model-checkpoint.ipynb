# %%
import os
import numpy as np
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model
import tensorflow as tf
# Out:
# WARNING:tensorflow:From C:\Users\anuru\anaconda3\envs\TF215_Env_Sam\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
img_folder = 'exam/flower'
model = load_model('models/flower_mode1.keras')

# กำหนดขนาดของภาพที่โมเดลต้องการ (224x224 สำหรับ VGG16)
img_height = 224
img_width = 224

# โหลดไฟล์ภาพทั้งหมดจากโฟลเดอร์
img_paths = [os.path.join(img_folder, fname) for fname in os.listdir(img_folder) if fname.endswith(('.png', '.jpg', '.jpeg'))]
images = []

# โหลดภาพทีละภาพและปรับขนาดให้ตรงกับขนาดที่โมเดลต้องการ
for img_path in img_paths:
    img = image.load_img(img_path, target_size=(img_height, img_width))
    img_array = image.img_to_array(img)  # แปลงภาพเป็น array
    img_array = np.expand_dims(img_array, axis=0)  # เพิ่ม dimension สำหรับ batch
    images.append(img_array)

images = np.vstack(images)
predictions = model.predict(images)

class_names = ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

for i, pred in enumerate(predictions):
    top_3_indices = np.argsort(pred)[::-1][:3]  # จัดลำดับจากมากไปน้อยแล้วเลือก 3 อันดับแรก
    print(f"Top 3 predictions for image {img_paths[i]}:")
    for index in top_3_indices:
        predicted_class = class_names[index]
        predicted_probability = pred[index] * 100  # ความน่าจะเป็นของคลาส
        print(f"{predicted_class}: {predicted_probability:.2f}%")
    print()
# Out:
# WARNING:tensorflow:From C:\Users\anuru\anaconda3\envs\TF215_Env_Sam\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\anuru\anaconda3\envs\TF215_Env_Sam\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# 1/1 [==============================] - 4s 4s/step
# Top 3 predictions for image exam/flower\10791227_7168491604.jpg:
# tulips: 99.44%
# roses: 0.56%
# daisy: 0.00%
#
# Top 3 predictions for image exam/flower\11746080_963537acdc.jpg:
# tulips: 94.70%
# roses: 5.30%
# daisy: 0.00%
#
# Top 3 predictions for image exam/flower\11746276_de3dec8201.jpg:
# tulips: 100.00%
# roses: 0.00%
# sunflowers: 0.00%
#
# Top 3 predictions for image exam/flower\11746367_d23a35b085_n.jpg:
# tulips: 94.42%
# roses: 5.58%
# daisy: 0.00%
#
# Top 3 predictions for image exam/flower\11746452_5bc1749a36.jpg:
# tulips: 100.00%
# roses: 0.00%
# sunflowers: 0.00%
#
# Top 3 predictions for image exam/flower\11746548_26b3256922_n.jpg:
# tulips: 100.00%
# roses: 0.00%
# daisy: 0.00%
#
# Top 3 predictions for image exam/flower\14957470_6a8c272a87_m.jpg:
# roses: 21.16%
# sunflowers: 20.65%
# tulips: 20.10%
#
# Top 3 predictions for image exam/flower\5673551_01d1ea993e_n.jpg:
# daisy: 48.25%
# sunflowers: 41.15%
# roses: 6.27%
#
# Top 3 predictions for image exam/flower\5673728_71b8cb57eb.jpg:
# roses: 21.16%
# sunflowers: 20.65%
# tulips: 20.10%
#
# Top 3 predictions for image exam/flower\5794835_d15905c7c8_n.jpg:
# daisy: 100.00%
# dandelion: 0.00%
# sunflowers: 0.00%
#
# Top 3 predictions for image exam/flower\5794839_200acd910c_n.jpg:
# daisy: 100.00%
# sunflowers: 0.00%
# dandelion: 0.00%
#
# Top 3 predictions for image exam/flower\7355522_b66e5d3078_m.jpg:
# roses: 21.16%
# sunflowers: 20.65%
# tulips: 20.10%
#
# Top 3 predictions for image exam/flower\8181477_8cb77d2e0f_n.jpg:
# dandelion: 32.75%
# sunflowers: 19.47%
# daisy: 18.35%
#
# Top 3 predictions for image exam/flower\8223949_2928d3f6f6_n.jpg:
# roses: 21.16%
# sunflowers: 20.65%
# tulips: 20.10%
#
# Top 3 predictions for image exam/flower\8223968_6b51555d2f_n.jpg:
# dandelion: 100.00%
# daisy: 0.00%
# tulips: 0.00%
